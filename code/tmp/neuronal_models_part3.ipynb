# %% [markdown]
# # Stimulus Driven Neuron Dynamics
# Some extra stuff I just came up with reading the materials again
#
# Interesting section: **Multistability and Working Memory**
#
# Take a winner-take-all rate model, let it simulate until an attractor state and then introduce a sudden spike to a certain neuron and at a certain point to all neurons. Expected behaviour: during spike period, the affected neuron is predominant; after spike period, network returns to the background state
#
# We will take a randomly connected network of excitatory and inhibitory neurons, as in part 2

# %%
# Import the necessary modules
import numpy as np 
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import torch 
from torch import nn, optim
from torchdiffeq import odeint
from functools import partial

# %%
from models import
